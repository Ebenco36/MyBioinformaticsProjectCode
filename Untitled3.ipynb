# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
Dataset = pd.read_csv('../../../normalizedCounts.csv')
Dataset_unnor = pd.read_csv('../../../UnnormalizedCounts.csv')

# %%
list(Dataset)
# df_new = Dataset.rename(columns={'A': 'Col_1'}, index={'ONE': 'Row_1'})
df_new = Dataset.rename(columns={'Unnamed: 0': ''})

# %%
# Save to file in csv format
df_new.to_csv('../../../NormalizedCountWithGeneColumnRenamed.csv')

# %%
df_index = df_new.set_index('')
df_index
# Transpose Data
df_data = df_index.T
df_data
# Out:
#             ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# GSM3483766         0.000000              0.0       529.140177
# GSM3483767        44.952409              0.0       553.973247
# GSM3483768        11.165171              0.0       480.439713
# GSM3483769        14.469272              0.0       484.567684
# GSM3483770         4.279977              0.0       492.648941
# GSM3483771         4.152739              0.0       345.021080
# GSM3483772        14.879515              0.0       545.756420
# GSM3483773        17.555295              0.0       293.250364
# GSM3483774         6.125484              0.0       472.963637
# GSM3483775        20.797903              0.0       334.311940
# GSM3483776         0.826033              0.0       157.511092
# GSM3483777         7.481540              0.0       196.382678
# GSM3483778        10.588192              0.0       252.773615
# GSM3483779         7.845811              0.0       192.315634
# GSM3483780         3.505092              0.0       299.355111
#
#             ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# GSM3483766       673.567131       506.361403     10285.520995
# GSM3483767       591.914072       405.691621     10583.087532
# GSM3483768       475.123887       219.682290      8264.060029
# GSM3483769       611.963211       332.000886     10671.264494
# GSM3483770       845.386131       400.852404     11017.586034
# GSM3483771       546.373085       238.828708      8664.697607
# GSM3483772       649.788620       434.090676     10402.346720
# GSM3483773       643.466977       267.103754      5436.976953
# GSM3483774       621.680815       339.462995     12132.899137
# GSM3483775       506.916385       178.348751     10604.339074
# GSM3483776       774.353410       175.536731     14144.862205
# GSM3483777       616.741576       169.758330     10911.952939
# GSM3483778       571.883274       155.927129      7751.734963
# GSM3483779       579.146087       171.983622      6188.009861
# GSM3483780       651.993838       151.146339      9596.176305
#
#             ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# GSM3483766       802.872558       623.235101       700.216423
# GSM3483767       348.086690       617.524305       472.476782
# GSM3483768       287.361873       545.334123       391.590547
# GSM3483769       305.890249       558.367338       335.531826
# GSM3483770       405.825317       337.382607       387.577637
# GSM3483771       543.240563       603.989755       757.497204
# GSM3483772       397.403616       732.865153       306.611504
# GSM3483773       268.332246       362.621636       349.564425
# GSM3483774       256.881599       598.151007       341.999620
# GSM3483775       166.458015       882.420472       506.842028
# GSM3483776        71.826351       607.488045       636.413733
# GSM3483777       122.395106       391.834951       673.494657
# GSM3483778       236.187644       403.959754       996.913721
# GSM3483779       263.448196       538.932481       960.389423
# GSM3483780       120.356611       489.943831      1115.664108
#
#             ENSG00000001167  ...  ENSG00000288635  ENSG00000288636  \
# GSM3483766      1051.381055  ...         0.000000         0.000000
# GSM3483767       822.582560  ...         0.000000         0.000000
# GSM3483768      1002.308382  ...         0.000000         8.339835
# GSM3483769       781.211901  ...         0.000000         0.000000
# GSM3483770       755.034839  ...         0.000000         0.000000
# GSM3483771      1214.417759  ...         0.000000         4.010174
# GSM3483772       804.215461  ...         0.000000         4.536671
# GSM3483773      1053.641610  ...         0.000000         5.946934
# GSM3483774       959.908633  ...         0.000000         6.856140
# GSM3483775      1204.045216  ...         4.777725         0.000000
# GSM3483776      1657.988920  ...         0.000000         0.000000
# GSM3483777      2125.216485  ...         0.000000         0.000000
# GSM3483778      1800.673918  ...         1.163506         5.540494
# GSM3483779      1322.644542  ...         0.000000         0.000000
# GSM3483780      1713.659449  ...         0.000000         0.000000
#
#             ENSG00000288637  ENSG00000288638  ENSG00000288639  \
# GSM3483766         9.811963         9.668889              0.0
# GSM3483767         1.890437         0.000000              0.0
# GSM3483768         0.000000         0.000000              0.0
# GSM3483769         0.000000         0.000000              0.0
# GSM3483770         0.000000         0.000000              0.0
# GSM3483771         0.000000         2.045897              0.0
# GSM3483772         3.975664         0.000000              0.0
# GSM3483773         0.000000         3.326991              0.0
# GSM3483774        18.524825         0.000000              0.0
# GSM3483775         9.498454         0.000000              0.0
# GSM3483776         5.735989         0.000000              0.0
# GSM3483777        17.404175         0.000000              0.0
# GSM3483778        13.853041         2.973082              0.0
# GSM3483779         6.766892         1.629470              0.0
# GSM3483780        12.169160         0.000000              0.0
#
#             ENSG00000288640  ENSG00000288642  ENSG00000288643  \
# GSM3483766        31.560433              0.0              0.0
# GSM3483767        79.130355              0.0              0.0
# GSM3483768        45.417521              0.0              0.0
# GSM3483769        92.233286              0.0              0.0
# GSM3483770       125.861904              0.0              0.0
# GSM3483771        24.836458              0.0              0.0
# GSM3483772         0.000000              0.0              0.0
# GSM3483773        64.309200              0.0              0.0
# GSM3483774        27.016672              0.0              0.0
# GSM3483775        60.555348              0.0              0.0
# GSM3483776        59.723061              0.0              0.0
# GSM3483777        62.020222              0.0              0.0
# GSM3483778        63.961566              0.0              0.0
# GSM3483779         0.000000              0.0              0.0
# GSM3483780        80.785823              0.0              0.0
#
#             ENSG00000288644  ENSG00000288645
# GSM3483766              0.0              0.0
# GSM3483767              0.0              0.0
# GSM3483768              0.0              0.0
# GSM3483769              0.0              0.0
# GSM3483770              0.0              0.0
# GSM3483771              0.0              0.0
# GSM3483772              0.0              0.0
# GSM3483773              0.0              0.0
# GSM3483774              0.0              0.0
# GSM3483775              0.0              0.0
# GSM3483776              0.0              0.0
# GSM3483777              0.0              0.0
# GSM3483778              0.0              0.0
# GSM3483779              0.0              0.0
# GSM3483780              0.0              0.0
#
# [15 rows x 60237 columns]

# %%
df_data['labels'] = [
    'subacute ischemic stroke', 
    'subacute ischemic stroke', 
    'subacute ischemic stroke', 
    'subacute ischemic stroke', 
    'subacute ischemic stroke', 
    'acute ischemic stroke', 
    'acute ischemic stroke', 
    'acute ischemic stroke', 
    'acute ischemic stroke', 
    'acute ischemic stroke', 
    'healthy control', 
    'healthy control', 
    'healthy control', 
    'healthy control', 
    'healthy control'
]

# %%
# Save new data

df_data.to_csv('../../../NormalizedCountWithGeneColumnLabels.csv')

# %%
# df_data.describe()

# %%
header = list(df_data.columns)
head_ = header.pop(60237)
len(header)
# Out:
# 60237

# %%
df_data.loc[:,header].values
# Out:
# array([[  0.        ,   0.        , 529.14017684, ...,   0.        ,
#           0.        ,   0.        ],
#        [ 44.95240851,   0.        , 553.97324745, ...,   0.        ,
#           0.        ,   0.        ],
#        [ 11.16517102,   0.        , 480.43971291, ...,   0.        ,
#           0.        ,   0.        ],
#        ...,
#        [ 10.58819152,   0.        , 252.77361479, ...,   0.        ,
#           0.        ,   0.        ],
#        [  7.84581058,   0.        , 192.31563417, ...,   0.        ,
#           0.        ,   0.        ],
#        [  3.50509179,   0.        , 299.35511117, ...,   0.        ,
#           0.        ,   0.        ]])

# %%
# Separating out the features
df_x = df_data.loc[:, header].values
# Separating out the target
df_y = df_data.loc[:,['labels']].values
# Standardizing the features
x = StandardScaler().fit_transform(df_x)

# %%
df_x_x = df_data.loc[:, df_data.isin([' ','NULL',0]).mean() < 1]

# %%
df_x_x.shape
# Out:
# (15, 33748)

# %%
df_x_x_zeros = df_data.loc[:, df_data.isin([' ','NULL',0]).mean() == 1]

# %%
df_x_x_zeros
# Out:
#             ENSG00000000005  ENSG00000001626  ENSG00000002079  \
# GSM3483766              0.0              0.0              0.0
# GSM3483767              0.0              0.0              0.0
# GSM3483768              0.0              0.0              0.0
# GSM3483769              0.0              0.0              0.0
# GSM3483770              0.0              0.0              0.0
# GSM3483771              0.0              0.0              0.0
# GSM3483772              0.0              0.0              0.0
# GSM3483773              0.0              0.0              0.0
# GSM3483774              0.0              0.0              0.0
# GSM3483775              0.0              0.0              0.0
# GSM3483776              0.0              0.0              0.0
# GSM3483777              0.0              0.0              0.0
# GSM3483778              0.0              0.0              0.0
# GSM3483779              0.0              0.0              0.0
# GSM3483780              0.0              0.0              0.0
#
#             ENSG00000003137  ENSG00000005073  ENSG00000006059  \
# GSM3483766              0.0              0.0              0.0
# GSM3483767              0.0              0.0              0.0
# GSM3483768              0.0              0.0              0.0
# GSM3483769              0.0              0.0              0.0
# GSM3483770              0.0              0.0              0.0
# GSM3483771              0.0              0.0              0.0
# GSM3483772              0.0              0.0              0.0
# GSM3483773              0.0              0.0              0.0
# GSM3483774              0.0              0.0              0.0
# GSM3483775              0.0              0.0              0.0
# GSM3483776              0.0              0.0              0.0
# GSM3483777              0.0              0.0              0.0
# GSM3483778              0.0              0.0              0.0
# GSM3483779              0.0              0.0              0.0
# GSM3483780              0.0              0.0              0.0
#
#             ENSG00000006071  ENSG00000006116  ENSG00000006128  \
# GSM3483766              0.0              0.0              0.0
# GSM3483767              0.0              0.0              0.0
# GSM3483768              0.0              0.0              0.0
# GSM3483769              0.0              0.0              0.0
# GSM3483770              0.0              0.0              0.0
# GSM3483771              0.0              0.0              0.0
# GSM3483772              0.0              0.0              0.0
# GSM3483773              0.0              0.0              0.0
# GSM3483774              0.0              0.0              0.0
# GSM3483775              0.0              0.0              0.0
# GSM3483776              0.0              0.0              0.0
# GSM3483777              0.0              0.0              0.0
# GSM3483778              0.0              0.0              0.0
# GSM3483779              0.0              0.0              0.0
# GSM3483780              0.0              0.0              0.0
#
#             ENSG00000006377  ...  ENSG00000288625  ENSG00000288626  \
# GSM3483766              0.0  ...              0.0              0.0
# GSM3483767              0.0  ...              0.0              0.0
# GSM3483768              0.0  ...              0.0              0.0
# GSM3483769              0.0  ...              0.0              0.0
# GSM3483770              0.0  ...              0.0              0.0
# GSM3483771              0.0  ...              0.0              0.0
# GSM3483772              0.0  ...              0.0              0.0
# GSM3483773              0.0  ...              0.0              0.0
# GSM3483774              0.0  ...              0.0              0.0
# GSM3483775              0.0  ...              0.0              0.0
# GSM3483776              0.0  ...              0.0              0.0
# GSM3483777              0.0  ...              0.0              0.0
# GSM3483778              0.0  ...              0.0              0.0
# GSM3483779              0.0  ...              0.0              0.0
# GSM3483780              0.0  ...              0.0              0.0
#
#             ENSG00000288629  ENSG00000288631  ENSG00000288633  \
# GSM3483766              0.0              0.0              0.0
# GSM3483767              0.0              0.0              0.0
# GSM3483768              0.0              0.0              0.0
# GSM3483769              0.0              0.0              0.0
# GSM3483770              0.0              0.0              0.0
# GSM3483771              0.0              0.0              0.0
# GSM3483772              0.0              0.0              0.0
# GSM3483773              0.0              0.0              0.0
# GSM3483774              0.0              0.0              0.0
# GSM3483775              0.0              0.0              0.0
# GSM3483776              0.0              0.0              0.0
# GSM3483777              0.0              0.0              0.0
# GSM3483778              0.0              0.0              0.0
# GSM3483779              0.0              0.0              0.0
# GSM3483780              0.0              0.0              0.0
#
#             ENSG00000288639  ENSG00000288642  ENSG00000288643  \
# GSM3483766              0.0              0.0              0.0
# GSM3483767              0.0              0.0              0.0
# GSM3483768              0.0              0.0              0.0
# GSM3483769              0.0              0.0              0.0
# GSM3483770              0.0              0.0              0.0
# GSM3483771              0.0              0.0              0.0
# GSM3483772              0.0              0.0              0.0
# GSM3483773              0.0              0.0              0.0
# GSM3483774              0.0              0.0              0.0
# GSM3483775              0.0              0.0              0.0
# GSM3483776              0.0              0.0              0.0
# GSM3483777              0.0              0.0              0.0
# GSM3483778              0.0              0.0              0.0
# GSM3483779              0.0              0.0              0.0
# GSM3483780              0.0              0.0              0.0
#
#             ENSG00000288644  ENSG00000288645
# GSM3483766              0.0              0.0
# GSM3483767              0.0              0.0
# GSM3483768              0.0              0.0
# GSM3483769              0.0              0.0
# GSM3483770              0.0              0.0
# GSM3483771              0.0              0.0
# GSM3483772              0.0              0.0
# GSM3483773              0.0              0.0
# GSM3483774              0.0              0.0
# GSM3483775              0.0              0.0
# GSM3483776              0.0              0.0
# GSM3483777              0.0              0.0
# GSM3483778              0.0              0.0
# GSM3483779              0.0              0.0
# GSM3483780              0.0              0.0
#
# [15 rows x 26490 columns]

# %%
df_data.isin([' ','NULL',0])['ENSG00000000005']
df_data.isin([' ','NULL',0])['ENSG00000000419']
# Out:
# GSM3483766    False
# GSM3483767    False
# GSM3483768    False
# GSM3483769    False
# GSM3483770    False
# GSM3483771    False
# GSM3483772    False
# GSM3483773    False
# GSM3483774    False
# GSM3483775    False
# GSM3483776    False
# GSM3483777    False
# GSM3483778    False
# GSM3483779    False
# GSM3483780    False
# Name: ENSG00000000419, dtype: bool

# %%
# Remove Label for analysis

df_without_label = df_x_x.drop(['labels'], axis=1)

# %%
df_without_label.shape
# Out:
# (15, 33747)

# %%
df3 = df_without_label[df_without_label.columns[df_without_label.mean() > 0.1]]

# %%
df3.shape
# Out:
# (15, 31703)

# %%
df3_less_than_0_1 = df_without_label[df_without_label.columns[df_without_label.mean() < 0.1]]

# %%
df3_less_than_0_1
# Out:
#             ENSG00000001617  ENSG00000004776  ENSG00000005421  \
# GSM3483766         0.000000          0.00000          0.00000
# GSM3483767         0.000000          0.00000          0.00000
# GSM3483768         0.000000          0.00000          0.00000
# GSM3483769         0.000000          0.00000          0.00000
# GSM3483770         0.000000          0.00000          0.00000
# GSM3483771         0.000000          0.00000          0.00000
# GSM3483772         0.000000          0.00000          0.00000
# GSM3483773         0.000000          0.00000          0.00000
# GSM3483774         0.000000          0.00000          0.00000
# GSM3483775         0.956553          0.00000          0.00000
# GSM3483776         0.000000          0.00000          0.00000
# GSM3483777         0.000000          0.00000          0.00000
# GSM3483778         0.000000          1.16228          1.16228
# GSM3483779         0.000000          0.00000          0.00000
# GSM3483780         0.000000          0.00000          0.00000
#
#             ENSG00000008118  ENSG00000020219  ENSG00000021852  \
# GSM3483766         0.000000         0.000000         0.000000
# GSM3483767         0.000000         0.000000         0.000000
# GSM3483768         0.000000         0.000000         0.000000
# GSM3483769         0.000000         1.009527         0.000000
# GSM3483770         0.000000         0.000000         0.000000
# GSM3483771         0.000000         0.000000         0.000000
# GSM3483772         0.000000         0.000000         0.000000
# GSM3483773         0.000000         0.000000         0.000000
# GSM3483774         0.000000         0.000000         0.000000
# GSM3483775         0.000000         0.000000         0.000000
# GSM3483776         0.000000         0.000000         0.000000
# GSM3483777         1.184191         0.000000         0.000000
# GSM3483778         0.000000         0.000000         0.000000
# GSM3483779         0.000000         0.000000         0.000000
# GSM3483780         0.000000         0.000000         1.222594
#
#             ENSG00000040731  ENSG00000041982  ENSG00000042813  \
# GSM3483766         0.896214         0.000000         0.000000
# GSM3483767         0.000000         0.000000         0.000000
# GSM3483768         0.000000         0.000000         0.000000
# GSM3483769         0.000000         0.000000         0.000000
# GSM3483770         0.000000         0.000000         0.000000
# GSM3483771         0.000000         0.000000         0.000000
# GSM3483772         0.000000         0.000000         0.000000
# GSM3483773         0.000000         0.000000         0.000000
# GSM3483774         0.000000         0.000000         0.000000
# GSM3483775         0.000000         0.000000         0.000000
# GSM3483776         0.000000         0.000000         0.000000
# GSM3483777         0.000000         0.000000         0.000000
# GSM3483778         0.000000         0.000000         0.000000
# GSM3483779         0.000000         1.129878         1.129878
# GSM3483780         0.000000         0.000000         0.000000
#
#             ENSG00000047662  ...  ENSG00000288045  ENSG00000288059  \
# GSM3483766          0.00000  ...         0.000000         0.000000
# GSM3483767          0.00000  ...         0.000000         0.000000
# GSM3483768          0.00000  ...         0.000000         0.000000
# GSM3483769          0.00000  ...         0.000000         1.009527
# GSM3483770          0.00000  ...         0.000000         0.000000
# GSM3483771          0.00000  ...         0.000000         0.000000
# GSM3483772          0.00000  ...         0.000000         0.000000
# GSM3483773          0.00000  ...         0.000000         0.000000
# GSM3483774          0.00000  ...         0.000000         0.000000
# GSM3483775          0.00000  ...         0.000000         0.000000
# GSM3483776          0.00000  ...         0.000000         0.000000
# GSM3483777          0.00000  ...         0.000000         0.000000
# GSM3483778          1.16228  ...         0.000000         0.000000
# GSM3483779          0.00000  ...         1.129878         0.000000
# GSM3483780          0.00000  ...         0.000000         0.000000
#
#             ENSG00000288065  ENSG00000288072  ENSG00000288100  \
# GSM3483766         0.000000         0.000000          0.00000
# GSM3483767         0.000000         0.000000          0.00000
# GSM3483768         0.000000         0.000000          0.00000
# GSM3483769         0.000000         0.000000          0.00000
# GSM3483770         0.000000         0.000000          0.00000
# GSM3483771         0.000000         0.000000          0.00000
# GSM3483772         0.000000         0.000000          0.00000
# GSM3483773         0.000000         0.000000          0.00000
# GSM3483774         0.000000         0.000000          0.00000
# GSM3483775         0.000000         0.000000          0.00000
# GSM3483776         0.000000         0.000000          0.00000
# GSM3483777         0.000000         0.000000          0.00000
# GSM3483778         0.000000         0.000000          1.16228
# GSM3483779         1.129878         0.000000          0.00000
# GSM3483780         0.000000         1.222594          0.00000
#
#             ENSG00000288153  ENSG00000288162  ENSG00000288437  \
# GSM3483766         0.000000         0.000000         0.000000
# GSM3483767         0.000000         0.000000         0.000000
# GSM3483768         0.000000         0.000000         0.000000
# GSM3483769         0.000000         0.000000         0.000000
# GSM3483770         0.000000         0.000000         0.000000
# GSM3483771         0.000000         0.000000         0.000000
# GSM3483772         0.000000         0.000000         0.000000
# GSM3483773         0.000000         0.000000         0.000000
# GSM3483774         0.000000         0.000000         0.000000
# GSM3483775         0.000000         0.000000         0.000000
# GSM3483776         0.000000         0.000000         0.000000
# GSM3483777         1.184191         0.000000         0.000000
# GSM3483778         0.000000         0.000000         0.000000
# GSM3483779         0.000000         0.000000         1.129878
# GSM3483780         0.000000         1.222594         0.000000
#
#             ENSG00000288588  ENSG00000288627
# GSM3483766         0.000000         0.000000
# GSM3483767         0.000000         0.000000
# GSM3483768         0.000000         0.000000
# GSM3483769         0.000000         0.000000
# GSM3483770         0.000000         0.000000
# GSM3483771         0.000000         0.000000
# GSM3483772         0.000000         0.000000
# GSM3483773         0.000000         0.000000
# GSM3483774         0.000000         0.000000
# GSM3483775         0.000000         0.000000
# GSM3483776         1.152779         1.152779
# GSM3483777         0.000000         0.000000
# GSM3483778         0.000000         0.000000
# GSM3483779         0.000000         0.000000
# GSM3483780         0.000000         0.000000
#
# [15 rows x 2044 columns]

# %%
# Get column data
df3['ENSG00000288640']

# get row data
df3.loc['GSM3483766']
# Out:
# ENSG00000000003        0.000000
# ENSG00000000419      529.140177
# ENSG00000000457      673.567131
# ENSG00000000460      506.361403
# ENSG00000000938    10285.520995
#                        ...
# ENSG00000288635        0.000000
# ENSG00000288636        0.000000
# ENSG00000288637        9.811963
# ENSG00000288638        9.668889
# ENSG00000288640       31.560433
# Name: GSM3483766, Length: 31703, dtype: float64

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(df3)
principalComponents
# Out:
# array([[ 6.80599629e+05, -9.68231824e+04,  1.95960697e+04],
#        [ 7.63122072e+05,  2.01791016e+03,  6.32164022e+04],
#        [ 3.51945451e+05, -9.26159157e+04,  2.88214381e+04],
#        [ 3.88863883e+05, -1.62784168e+05, -1.48698427e+05],
#        [ 1.43495551e+06,  2.49294939e+05, -3.32070458e+04],
#        [-4.06187993e+05, -6.07584244e+04,  4.73838955e+03],
#        [ 8.37135930e+05, -2.35198821e+04,  3.33756815e+04],
#        [-1.95431745e+05, -3.14822479e+04,  2.69709193e+05],
#        [ 2.54332339e+05, -5.59462607e+04, -9.83345631e+04],
#        [-4.26583729e+05,  7.44609242e+03, -4.31855436e+04],
#        [-6.91590950e+05,  9.75449335e+04, -4.36943557e+04],
#        [-7.44819344e+05,  6.13144132e+04,  9.51107669e+02],
#        [-6.85974583e+05,  4.23219337e+04, -3.99873669e+04],
#        [-7.92791198e+05, -2.70651707e+03,  4.62400083e+03],
#        [-7.67575276e+05,  6.66963770e+04, -1.79249806e+04]])

# %%
principal_df = pd.DataFrame(data = principalComponents
             , columns = ['p1', 'p2', 'p3'],
            index=df3.index.values)

# %%
principal_df
# Out:
#                       p1             p2             p3
# GSM3483766  6.805996e+05  -96823.182374   19596.069697
# GSM3483767  7.631221e+05    2017.910162   63216.402234
# GSM3483768  3.519455e+05  -92615.915672   28821.438069
# GSM3483769  3.888639e+05 -162784.168368 -148698.426664
# GSM3483770  1.434956e+06  249294.938670  -33207.045753
# GSM3483771 -4.061880e+05  -60758.424399    4738.389552
# GSM3483772  8.371359e+05  -23519.882060   33375.681455
# GSM3483773 -1.954317e+05  -31482.247923  269709.192832
# GSM3483774  2.543323e+05  -55946.260674  -98334.563126
# GSM3483775 -4.265837e+05    7446.092417  -43185.543561
# GSM3483776 -6.915909e+05   97544.933452  -43694.355704
# GSM3483777 -7.448193e+05   61314.413178     951.107669
# GSM3483778 -6.859746e+05   42321.933703  -39987.366929
# GSM3483779 -7.927912e+05   -2706.517074    4624.000828
# GSM3483780 -7.675753e+05   66696.376963  -17924.980600

# %%
df3.index.values
# Out:
# array(['GSM3483766', 'GSM3483767', 'GSM3483768', 'GSM3483769',
#        'GSM3483770', 'GSM3483771', 'GSM3483772', 'GSM3483773',
#        'GSM3483774', 'GSM3483775', 'GSM3483776', 'GSM3483777',
#        'GSM3483778', 'GSM3483779', 'GSM3483780'], dtype=object)

# %%
df_data[['labels']]
# Out:
#                               labels
# GSM3483766  subacute ischemic stroke
# GSM3483767  subacute ischemic stroke
# GSM3483768  subacute ischemic stroke
# GSM3483769  subacute ischemic stroke
# GSM3483770  subacute ischemic stroke
# GSM3483771     acute ischemic stroke
# GSM3483772     acute ischemic stroke
# GSM3483773     acute ischemic stroke
# GSM3483774     acute ischemic stroke
# GSM3483775     acute ischemic stroke
# GSM3483776           healthy control
# GSM3483777           healthy control
# GSM3483778           healthy control
# GSM3483779           healthy control
# GSM3483780           healthy control

# %%
final_df = pd.concat([principal_df, df_data[['labels']]], axis = 1)

# %%
final_df
# Out:
#                       p1             p2             p3  \
# GSM3483766  6.805996e+05  -96823.182374   19596.069697
# GSM3483767  7.631221e+05    2017.910162   63216.402234
# GSM3483768  3.519455e+05  -92615.915672   28821.438069
# GSM3483769  3.888639e+05 -162784.168368 -148698.426664
# GSM3483770  1.434956e+06  249294.938670  -33207.045753
# GSM3483771 -4.061880e+05  -60758.424399    4738.389552
# GSM3483772  8.371359e+05  -23519.882060   33375.681455
# GSM3483773 -1.954317e+05  -31482.247923  269709.192832
# GSM3483774  2.543323e+05  -55946.260674  -98334.563126
# GSM3483775 -4.265837e+05    7446.092417  -43185.543561
# GSM3483776 -6.915909e+05   97544.933452  -43694.355704
# GSM3483777 -7.448193e+05   61314.413178     951.107669
# GSM3483778 -6.859746e+05   42321.933703  -39987.366929
# GSM3483779 -7.927912e+05   -2706.517074    4624.000828
# GSM3483780 -7.675753e+05   66696.376963  -17924.980600
#
#                               labels
# GSM3483766  subacute ischemic stroke
# GSM3483767  subacute ischemic stroke
# GSM3483768  subacute ischemic stroke
# GSM3483769  subacute ischemic stroke
# GSM3483770  subacute ischemic stroke
# GSM3483771     acute ischemic stroke
# GSM3483772     acute ischemic stroke
# GSM3483773     acute ischemic stroke
# GSM3483774     acute ischemic stroke
# GSM3483775     acute ischemic stroke
# GSM3483776           healthy control
# GSM3483777           healthy control
# GSM3483778           healthy control
# GSM3483779           healthy control
# GSM3483780           healthy control

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('p1', fontsize = 15)
ax.set_ylabel('p2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['subacute ischemic stroke', 'acute ischemic stroke', 'healthy control']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = final_df['labels'] == target
    ax.scatter(final_df.loc[indicesToKeep, 'p1']
               , final_df.loc[indicesToKeep, 'p2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.93650195, 0.01737559, 0.01519889])

# %%
print(pca.explained_variance_)
print(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [5.17977953e+11 9.61041721e+09 8.40648689e+09]
# [0.93650195 0.01737559 0.01519889]
# [0.93650195 0.95387754 0.96907643]

# %%
header_df3 = list(df3.columns)

# %%
train_data, test_data, train_lbl, test_lbl = train_test_split( df3.loc[:,header_df3].values, 
                                                              final_df['labels'], 
                                                              test_size=1/7.0, 
                                                              random_state=42, shuffle=True)

# %%
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(train_data)
# Apply transform to both the training set and the test set.
train_data_ = scaler.transform(train_data)
test_data_ = scaler.transform(test_data)

# %%
pca = PCA(.60)

# %%
pca
pca.fit(train_data_)
# Out:
# PCA(n_components=0.6)

# %%
# Get predicted classes
pca.n_components_
# Out:
# 5

# %%
train_data_transform = pca.transform(train_data_)
test_data_transform = pca.transform(test_data_)

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
# Out:
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=True,
custom_metric=None, predictions=True)
models,pred = reg.fit(train_data, test_data, train_lbl, test_lbl)
# Out:
#  98%|█████████▊| 41/42 [00:17<00:00,  2.87it/s]
